# %% [markdown]
# # Scraper

# %% [markdown]
# ### Imports

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# ### Base Variables

# %%
BASE_URL = "https://statsapi.mlb.com/api/v1/"
TEAM_ID = 138
TEAM_INFO = pd.read_html("./team_info.html")[0]

# %% [markdown]
# ### Functions

# %%
def team_roster(type="pretty", active=False):

    valid_types = ["pretty", "raw"]
    if type not in valid_types:
        raise ValueError("\"type\" argument must be pretty or raw")
    
    url = BASE_URL + f"teams/{TEAM_ID}/roster/40Man"
    res = requests.get(url).json()
    raw = res["roster"]

    roster = []

    for player in raw:
        obj = {}

        # Defaults (always included)
        obj["Name"] = player["person"]["fullName"]
        obj["Jersey"] = int(player["jerseyNumber"])
        obj["Pos"] = player["position"]["abbreviation"]

        if type == "pretty":
            obj["Status"] = player["status"]["description"]


        if type == "raw":
            obj["link"] = player["person"]["link"]
            obj["Status"] = player["status"]["code"]

        roster.append(obj)

    roster = pd.DataFrame(roster)

    if active:
        roster = roster[roster["Status"].isin(["Active", "A"])]

    return roster

# %%
def team_stats(group="hitting"):
    valid_groups = ["hitting", "pitching", "fielding", "catching"]

    if group not in valid_groups:
        return ValueError("group must be hitting, fielding, catching, or pitching")

    url = BASE_URL + f"teams/{TEAM_ID}/stats"
    params = {
        "group": "hitting",
        "stats": "gameLog",
        "season": "2024"
    }

    res = requests.get(url, params=params).json()["stats"][0]["splits"]
    
    
team_stats()
# Out:
# [{'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 4,
#    'airOuts': 18,
#    'runs': 1,
#    'doubles': 0,
#    'triples': 0,
#    'homeRuns': 1,
#    'strikeOuts': 6,
#    'baseOnBalls': 1,
#    'intentionalWalks': 0,
#    'hits': 3,
#    'hitByPitch': 0,
#    'avg': '.097',
#    'atBats': 31,
#    'obp': '.125',
#    'slg': '.194',
#    'ops': '.319',
#    'caughtStealing': 0,
#    'stolenBases': 1,
#    'stolenBasePercentage': '1.000',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 125,
#    'plateAppearances': 32,
#    'totalBases': 6,
#    'rbi': 1,
#    'leftOnBase': 4,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.083',
#    'groundOutsToAirouts': '0.22',
#    'atBatsPerHomeRun': '31.00'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 119, 'link': '/api/v1/teams/119'},
#   'date': '2024-03-28',
#   'isHome': False,
#   'isWin': False,
#   'game': {'gamePk': 746165,
#    'link': '/api/v1.1/game/746165/feed/live',
#    'content': {'link': '/api/v1/game/746165/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 6,
#    'airOuts': 7,
#    'runs': 3,
#    'doubles': 1,
#    'triples': 0,
#    'homeRuns': 0,
#    'strikeOuts': 14,
#    'baseOnBalls': 2,
#    'intentionalWalks': 0,
#    'hits': 6,
#    'hitByPitch': 1,
#    'avg': '.188',
#    'atBats': 32,
#    'obp': '.250',
#    'slg': '.219',
#    'ops': '.469',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 146,
#    'plateAppearances': 36,
#    'totalBases': 7,
#    'rbi': 3,
#    'leftOnBase': 6,
#    'sacBunts': 0,
#    'sacFlies': 1,
#    'babip': '.316',
#    'groundOutsToAirouts': '0.86',
#    'atBatsPerHomeRun': '-.--'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 119, 'link': '/api/v1/teams/119'},
#   'date': '2024-03-29',
#   'isHome': False,
#   'isWin': False,
#   'game': {'gamePk': 746167,
#    'link': '/api/v1.1/game/746167/feed/live',
#    'content': {'link': '/api/v1/game/746167/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 8,
#    'airOuts': 12,
#    'runs': 6,
#    'doubles': 2,
#    'triples': 0,
#    'homeRuns': 0,
#    'strikeOuts': 10,
#    'baseOnBalls': 2,
#    'intentionalWalks': 1,
#    'hits': 7,
#    'hitByPitch': 1,
#    'avg': '.194',
#    'atBats': 36,
#    'obp': '.250',
#    'slg': '.250',
#    'ops': '.500',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 146,
#    'plateAppearances': 41,
#    'totalBases': 9,
#    'rbi': 5,
#    'leftOnBase': 6,
#    'sacBunts': 0,
#    'sacFlies': 1,
#    'babip': '.259',
#    'groundOutsToAirouts': '0.67',
#    'atBatsPerHomeRun': '-.--'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 119, 'link': '/api/v1/teams/119'},
#   'date': '2024-03-30',
#   'isHome': False,
#   'isWin': True,
#   'game': {'gamePk': 746168,
#    'link': '/api/v1.1/game/746168/feed/live',
#    'content': {'link': '/api/v1/game/746168/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 8,
#    'airOuts': 6,
#    'runs': 4,
#    'doubles': 1,
#    'triples': 0,
#    'homeRuns': 0,
#    'strikeOuts': 13,
#    'baseOnBalls': 3,
#    'intentionalWalks': 0,
#    'hits': 8,
#    'hitByPitch': 1,
#    'avg': '.235',
#    'atBats': 34,
#    'obp': '.316',
#    'slg': '.265',
#    'ops': '.581',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 161,
#    'plateAppearances': 40,
#    'totalBases': 9,
#    'rbi': 4,
#    'leftOnBase': 9,
#    'sacBunts': 1,
#    'sacFlies': 0,
#    'babip': '.381',
#    'groundOutsToAirouts': '1.33',
#    'atBatsPerHomeRun': '-.--'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 119, 'link': '/api/v1/teams/119'},
#   'date': '2024-03-31',
#   'isHome': False,
#   'isWin': False,
#   'game': {'gamePk': 746166,
#    'link': '/api/v1.1/game/746166/feed/live',
#    'content': {'link': '/api/v1/game/746166/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 4,
#    'airOuts': 10,
#    'runs': 6,
#    'doubles': 2,
#    'triples': 0,
#    'homeRuns': 2,
#    'strikeOuts': 13,
#    'baseOnBalls': 3,
#    'intentionalWalks': 0,
#    'hits': 14,
#    'hitByPitch': 1,
#    'avg': '.341',
#    'atBats': 41,
#    'obp': '.400',
#    'slg': '.537',
#    'ops': '.937',
#    'caughtStealing': 0,
#    'stolenBases': 1,
#    'stolenBasePercentage': '1.000',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 173,
#    'plateAppearances': 45,
#    'totalBases': 22,
#    'rbi': 6,
#    'leftOnBase': 12,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.462',
#    'groundOutsToAirouts': '0.40',
#    'atBatsPerHomeRun': '20.50'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 135, 'link': '/api/v1/teams/135'},
#   'date': '2024-04-01',
#   'isHome': False,
#   'isWin': True,
#   'game': {'gamePk': 745437,
#    'link': '/api/v1.1/game/745437/feed/live',
#    'content': {'link': '/api/v1/game/745437/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 13,
#    'airOuts': 7,
#    'runs': 5,
#    'doubles': 2,
#    'triples': 0,
#    'homeRuns': 1,
#    'strikeOuts': 7,
#    'baseOnBalls': 4,
#    'intentionalWalks': 0,
#    'hits': 6,
#    'hitByPitch': 0,
#    'avg': '.207',
#    'atBats': 29,
#    'obp': '.286',
#    'slg': '.379',
#    'ops': '.665',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 1,
#    'numberOfPitches': 124,
#    'plateAppearances': 37,
#    'totalBases': 11,
#    'rbi': 4,
#    'leftOnBase': 5,
#    'sacBunts': 2,
#    'sacFlies': 2,
#    'babip': '.217',
#    'groundOutsToAirouts': '1.86',
#    'atBatsPerHomeRun': '29.00'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 135, 'link': '/api/v1/teams/135'},
#   'date': '2024-04-02',
#   'isHome': False,
#   'isWin': True,
#   'game': {'gamePk': 745439,
#    'link': '/api/v1.1/game/745439/feed/live',
#    'content': {'link': '/api/v1/game/745439/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 5,
#    'airOuts': 6,
#    'runs': 2,
#    'doubles': 1,
#    'triples': 0,
#    'homeRuns': 0,
#    'strikeOuts': 11,
#    'baseOnBalls': 4,
#    'intentionalWalks': 0,
#    'hits': 6,
#    'hitByPitch': 4,
#    'avg': '.214',
#    'atBats': 28,
#    'obp': '.389',
#    'slg': '.250',
#    'ops': '.639',
#    'caughtStealing': 2,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.000',
#    'groundIntoDoublePlay': 3,
#    'numberOfPitches': 155,
#    'plateAppearances': 36,
#    'totalBases': 7,
#    'rbi': 1,
#    'leftOnBase': 7,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.353',
#    'groundOutsToAirouts': '0.83',
#    'atBatsPerHomeRun': '-.--'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 135, 'link': '/api/v1/teams/135'},
#   'date': '2024-04-03',
#   'isHome': False,
#   'isWin': False,
#   'game': {'gamePk': 745440,
#    'link': '/api/v1.1/game/745440/feed/live',
#    'content': {'link': '/api/v1/game/745440/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 7,
#    'airOuts': 9,
#    'runs': 8,
#    'doubles': 2,
#    'triples': 1,
#    'homeRuns': 1,
#    'strikeOuts': 9,
#    'baseOnBalls': 3,
#    'intentionalWalks': 0,
#    'hits': 10,
#    'hitByPitch': 2,
#    'avg': '.286',
#    'atBats': 35,
#    'obp': '.375',
#    'slg': '.486',
#    'ops': '.861',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 1,
#    'numberOfPitches': 164,
#    'plateAppearances': 40,
#    'totalBases': 17,
#    'rbi': 8,
#    'leftOnBase': 8,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.360',
#    'groundOutsToAirouts': '0.78',
#    'atBatsPerHomeRun': '35.00'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 146, 'link': '/api/v1/teams/146'},
#   'date': '2024-04-04',
#   'isHome': True,
#   'isWin': True,
#   'game': {'gamePk': 745200,
#    'link': '/api/v1.1/game/745200/feed/live',
#    'content': {'link': '/api/v1/game/745200/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 15,
#    'airOuts': 5,
#    'runs': 3,
#    'doubles': 3,
#    'triples': 0,
#    'homeRuns': 0,
#    'strikeOuts': 3,
#    'baseOnBalls': 4,
#    'intentionalWalks': 0,
#    'hits': 8,
#    'hitByPitch': 0,
#    'avg': '.258',
#    'atBats': 31,
#    'obp': '.343',
#    'slg': '.355',
#    'ops': '.698',
#    'caughtStealing': 1,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.000',
#    'groundIntoDoublePlay': 1,
#    'numberOfPitches': 133,
#    'plateAppearances': 35,
#    'totalBases': 11,
#    'rbi': 2,
#    'leftOnBase': 8,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.286',
#    'groundOutsToAirouts': '3.00',
#    'atBatsPerHomeRun': '-.--'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 146, 'link': '/api/v1/teams/146'},
#   'date': '2024-04-06',
#   'isHome': True,
#   'isWin': True,
#   'game': {'gamePk': 745197,
#    'link': '/api/v1.1/game/745197/feed/live',
#    'content': {'link': '/api/v1/game/745197/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 11,
#    'airOuts': 7,
#    'runs': 3,
#    'doubles': 1,
#    'triples': 1,
#    'homeRuns': 2,
#    'strikeOuts': 9,
#    'baseOnBalls': 2,
#    'intentionalWalks': 0,
#    'hits': 5,
#    'hitByPitch': 0,
#    'avg': '.156',
#    'atBats': 32,
#    'obp': '.206',
#    'slg': '.438',
#    'ops': '.644',
#    'caughtStealing': 0,
#    'stolenBases': 0,
#    'stolenBasePercentage': '.---',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 133,
#    'plateAppearances': 34,
#    'totalBases': 14,
#    'rbi': 3,
#    'leftOnBase': 4,
#    'sacBunts': 0,
#    'sacFlies': 0,
#    'babip': '.143',
#    'groundOutsToAirouts': '1.57',
#    'atBatsPerHomeRun': '16.00'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 146, 'link': '/api/v1/teams/146'},
#   'date': '2024-04-07',
#   'isHome': True,
#   'isWin': False,
#   'game': {'gamePk': 745198,
#    'link': '/api/v1.1/game/745198/feed/live',
#    'content': {'link': '/api/v1/game/745198/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}},
#  {'season': '2024',
#   'stat': {'gamesPlayed': 1,
#    'groundOuts': 9,
#    'airOuts': 10,
#    'runs': 3,
#    'doubles': 2,
#    'triples': 0,
#    'homeRuns': 1,
#    'strikeOuts': 11,
#    'baseOnBalls': 3,
#    'intentionalWalks': 0,
#    'hits': 6,
#    'hitByPitch': 1,
#    'avg': '.171',
#    'atBats': 35,
#    'obp': '.250',
#    'slg': '.314',
#    'ops': '.564',
#    'caughtStealing': 0,
#    'stolenBases': 1,
#    'stolenBasePercentage': '1.000',
#    'groundIntoDoublePlay': 0,
#    'numberOfPitches': 164,
#    'plateAppearances': 40,
#    'totalBases': 11,
#    'rbi': 3,
#    'leftOnBase': 8,
#    'sacBunts': 0,
#    'sacFlies': 1,
#    'babip': '.208',
#    'groundOutsToAirouts': '0.90',
#    'atBatsPerHomeRun': '35.00'},
#   'team': {'id': 138,
#    'name': 'St. Louis Cardinals',
#    'link': '/api/v1/teams/138'},
#   'opponent': {'id': 143, 'link': '/api/v1/teams/143'},
#   'date': '2024-04-08',
#   'isHome': True,
#   'isWin': False,
#   'game': {'gamePk': 745194,
#    'link': '/api/v1.1/game/745194/feed/live',
#    'content': {'link': '/api/v1/game/745194/content'},
#    'gameNumber': 1,
#    'dayNight': 'day'}}]

# %%
TEAM_INFO
# Out:
#     Team ID Code File Code Abbreviation           Name  \
# 0       108  ana       ana          LAA      LA Angels
# 1       109  ari       ari          ARI        Arizona
# 2       110  bal       bal          BAL      Baltimore
# 3       111  bos       bos          BOS         Boston
# 4       112  chn       chc          CHC       Chi Cubs
# 5       113  cin       cin          CIN     Cincinnati
# 6       114  cle       cle          CLE      Cleveland
# 7       115  col       col          COL       Colorado
# 8       116  det       det          DET        Detroit
# 9       117  hou       hou          HOU        Houston
# 10      118  kca        kc           KC    Kansas City
# 11      119  lan        la          LAD     LA Dodgers
# 12      120  was       was          WSH     Washington
# 13      121  nyn       nym          NYM        NY Mets
# 14      133  oak       oak          OAK        Oakland
# 15      134  pit       pit          PIT     Pittsburgh
# 16      135  sdn        sd           SD      San Diego
# 17      136  sea       sea          SEA        Seattle
# 18      137  sfn        sf           SF  San Francisco
# 19      138  sln       stl          STL      St. Louis
# 20      139  tba        tb           TB      Tampa Bay
# 21      140  tex       tex          TEX          Texas
# 22      141  tor       tor          TOR        Toronto
# 23      142  min       min          MIN      Minnesota
# 24      143  phi       phi          PHI   Philadelphia
# 25      144  atl       atl          ATL        Atlanta
# 26      145  cha       cws          CWS  Chi White Sox
# 27      146  mia       mia          MIA          Miami
# 28      147  nya       nyy          NYY     NY Yankees
# 29      158  mil       mil          MIL      Milwaukee
# 30      159  aas        al           AL   AL All-Stars
# 31      160  nas        nl           NL   NL All-Stars
#
#                     Full Name    Brief Name
# 0          Los Angeles Angels        Angels
# 1        Arizona Diamondbacks       D-backs
# 2           Baltimore Orioles       Orioles
# 3              Boston Red Sox       Red Sox
# 4                Chicago Cubs          Cubs
# 5             Cincinnati Reds          Reds
# 6           Cleveland Indians       Indians
# 7            Colorado Rockies       Rockies
# 8              Detroit Tigers        Tigers
# 9              Houston Astros        Astros
# 10         Kansas City Royals        Royals
# 11        Los Angeles Dodgers       Dodgers
# 12       Washington Nationals     Nationals
# 13              New York Mets          Mets
# 14          Oakland Athletics     Athletics
# 15         Pittsburgh Pirates       Pirates
# 16           San Diego Padres        Padres
# 17           Seattle Mariners      Mariners
# 18       San Francisco Giants        Giants
# 19        St. Louis Cardinals     Cardinals
# 20             Tampa Bay Rays          Rays
# 21              Texas Rangers       Rangers
# 22          Toronto Blue Jays     Blue Jays
# 23            Minnesota Twins         Twins
# 24      Philadelphia Phillies      Phillies
# 25             Atlanta Braves        Braves
# 26          Chicago White Sox     White Sox
# 27              Miami Marlins       Marlins
# 28           New York Yankees       Yankees
# 29          Milwaukee Brewers       Brewers
# 30  American League All-Stars  AL All-Stars
# 31  National League All-Stars  NL All-Stars
